# %% [markdown]
# # Amazon Web Scrapping Project

# %%
# Importing Libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# getting the data
url = 'https://www.amazon.in/Fuda-While-Printed-Sleeve-Cotton/dp/B0CY4P4FH1/ref=sr_1_6?dib=eyJ2IjoiMSJ9.iXbXz4jN7MFWUwK-P_oNl6nyCRPMpyvh8KDGqe7_BYZOitqf6z5ISopbnd8SB-Yk-s4F7yp91fyb4dpn4ujt4agQ7WT59QLKinTc-G_iy1BjS-ZJxk5ADakEjgJWPvTATvgOzZeWUjaZg8Ps9gXl9Bc8RGvKEi-_oh_vytYQfeZoLeJXoUCr-O2GEiGEIRuj0iMuxJERtGh2nwDi8Z6MtvHfukLZ12bnpI6Yc8Rlgrw8bszdMzMG-Xd87tgbmpbEf5MHciz-vHEjPb5nN_Gyc6XrluU2MI6LuSGDBl9GF7E.zd6glhhfrrdC_BXrPyWzNckQI3-Y_1zTUA9HUywaacM&dib_tag=se&keywords=data%2B%2B%2Banalyst%2B%2B%2Btshirt&qid=1773895804&s=apparel&sr=1-6&th=1&psc=1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36 Edg/146.0.0.0"}
page = requests.get(url , headers=headers)

soup1 = BeautifulSoup(page.content , "html.parser")

soup2 = BeautifulSoup(soup1.prettify() , "html.parser")

title = soup2.find(id='productTitle').get_text()
price = soup2.find(class_='a-price-whole').get_text()
color = soup2.find(id="inline-twister-expanded-dimension-text-color_name").get_text()
size = soup2.find(id="inline-twister-expanded-dimension-text-size_name").get_text()
Material = soup2.find(class_="a-fixed-left-grid-col a-col-right").get_text()

# %%
items = soup2.find_all("li")

country = "N/A"

for item in items:
    text = item.get_text(strip=True)
    if "Country of Origin" in text:
        country = text.split(":")[-1].strip()
        break

print(country)
# Out:
# ‎India

# %%
today = datetime.date.today()
print(today)
# Out:
# 2026-03-19

# %%
# cleaning
price = price.strip()
title = title.strip()
color = color.strip()
size = size.strip()
Material = Material.strip()
country = country.strip()

print(title)
print(price)
print(color)
print(size)
print(Material)
print(country)
# Out:
# DUDEME Fuda: While Alive Eat Sleep Code Geek Printed Half Sleeve Cotton T Shirt for Men & Women
# 499
# Black
# L
# 100% Cotton
# ‎India

# %%
# conveting into csv
import csv

header = ['Title' , 'Price' , 'Color' , 'Size' , 'Material' , 'Country' , 'Date']
data = [title , price , color , size , Material , country , today]

with open('AmazonWebScrappingDataset.csv' , 'w' , newline = '' , encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'AmazonWebScrappingDataset.csv')

print(df)
# Out:
#                                                Title  Price  Color Size  \
# 0  DUDEME Fuda: While Alive Eat Sleep Code Geek P...    499  Black    L
#
#       Material Country        Date
# 0  100% Cotton  ‎India  2026-03-19

# %%
with open('AmazonWebScrappingDataset.csv' , 'a+' , newline = '' , encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    # getting the data
    url = 'https://www.amazon.in/Fuda-While-Printed-Sleeve-Cotton/dp/B0CY4P4FH1/ref=sr_1_6?dib=eyJ2IjoiMSJ9.iXbXz4jN7MFWUwK-P_oNl6nyCRPMpyvh8KDGqe7_BYZOitqf6z5ISopbnd8SB-Yk-s4F7yp91fyb4dpn4ujt4agQ7WT59QLKinTc-G_iy1BjS-ZJxk5ADakEjgJWPvTATvgOzZeWUjaZg8Ps9gXl9Bc8RGvKEi-_oh_vytYQfeZoLeJXoUCr-O2GEiGEIRuj0iMuxJERtGh2nwDi8Z6MtvHfukLZ12bnpI6Yc8Rlgrw8bszdMzMG-Xd87tgbmpbEf5MHciz-vHEjPb5nN_Gyc6XrluU2MI6LuSGDBl9GF7E.zd6glhhfrrdC_BXrPyWzNckQI3-Y_1zTUA9HUywaacM&dib_tag=se&keywords=data%2B%2B%2Banalyst%2B%2B%2Btshirt&qid=1773895804&s=apparel&sr=1-6&th=1&psc=1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36 Edg/146.0.0.0"}
    page = requests.get(url , headers=headers)
    
    soup1 = BeautifulSoup(page.content , "html.parser")
    
    soup2 = BeautifulSoup(soup1.prettify() , "html.parser")
    
    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(class_='a-price-whole').get_text()
    color = soup2.find(id="inline-twister-expanded-dimension-text-color_name").get_text()
    size = soup2.find(id="inline-twister-expanded-dimension-text-size_name").get_text()
    Material = soup2.find(class_="a-fixed-left-grid-col a-col-right").get_text()

    items = soup2.find_all("li")
    
    country = "N/A"
    
    for item in items:
        text = item.get_text(strip=True)
        if "Country of Origin" in text:
            country = text.split(":")[-1].strip()
            break


    today = datetime.date.today()
    print(today)
    
    

    price = price.strip()
    title = title.strip()
    color = color.strip()
    size = size.strip()
    Material = Material.strip()
    country = country.strip()
    
    print(title)
    print(price)
    print(color)
    print(size)
    print(Material)
    print(country)

    
    import csv

    header = ['Title' , 'Price' , 'Color' , 'Size' , 'Material' , 'Country' , 'Date']
    data = [title , price , color , size , Material , country , today]


    with open('AmazonWebScrappingDataset.csv' , 'a+' , newline = '' , encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)


    if(price <= 400):
        send_mail()

# %%
#while(True):
 #   check_price()
  #  time.sleep(86400) 24-Hour

# %%
import pandas as pd

df = pd.read_csv(r'AmazonWebScrappingDataset.csv')

print(df)
# Out:
#                                                Title  Price  Color Size  \
# 0  DUDEME Fuda: While Alive Eat Sleep Code Geek P...    499  Black    L
# 1  DUDEME Fuda: While Alive Eat Sleep Code Geek P...    499  Black    L
#
#       Material Country        Date
# 0  100% Cotton  ‎India  2026-03-19
# 1  100% Cotton  ‎India  2026-03-19

# %%
# Mail Automation 

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    server.login('guruuu2468@gmail.com' , 'xxxxxxxxxxxxxx')


    subject = "The T-shirt you want to buy is below 400 ! This is your chance to buy !"
    body = "Guru ! This is the moment you have been waiting for ! this is the great chance to buy your T-shirt at this price ! Don't miss this opportunity!"


    msg = f"Subject : {subject}\n\n{body}"
    
    server.sendmail(
        'guruuu2468@gmail.com',
         msg
    )
